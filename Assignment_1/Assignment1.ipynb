# %%
print("Alex")
print("Alex")
print("Alex")
# Out:
# Alex
# Alex
# Alex

# %%
a = 20
b = 40
c = 60
result = a+b+c
print(result)
# Out:
# 120

# %%
a = "New Delhi"
b = "New York"
c = "Australia"
print(a+" " +b+" "+c)
# Out:
# New Delhi New York Australia

# %%
print("Table of 7:")
for i in range(1, 11):
    print(f"7 x {i} = {7*i}")

print("\nTable of 9:")
for i in range(1, 11):
    print(f"9 x {i} = {9*i}")
# Out:
# Table of 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
# Table of 9:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %%
n = int(input("Enter a number: "))

print(f"\nTable of {n}:")
for i in range(1, 11):
    print(f"{n} x {i} = {n*i}")
# Out:
# Enter a number:  5
# Table of 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
n = int(input("Enter a number: "))
total = 0
for i in range(1, n+1):
    total += i

print(f"Sum of numbers from 1 to {n} = {total}")
# Out:
# Enter a number:  5
# Sum of numbers from 1 to 5 = 15

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
maximum = max(a, b, c)

print("The maximum number is:", maximum)
# Out:
# Enter first number:  33
# Enter second number:  85
# Enter third number:  300
# The maximum number is: 300

# %%
n = int(input("Enter a number: "))

total = 0
for i in range(1, n+1):
    if i % 7 == 0 or i % 9 == 0: 
        total += i

print("Sum of numbers divisible by 7 or 9 from 1 to", n, "is:", total)
# Out:
# Enter a number:  63
# Sum of numbers divisible by 7 or 9 from 1 to 63 is: 504

# %%
n = int(input("Enter a number: "))
total = 0

for num in range(2, n+1):
    f = 0
    for i in range(2, num//2 + 1):
        if num % i == 0:
            f = 1
            break
    if f == 0:
        total += num

print("Sum of prime numbers from 1 to", n, "is:", total)
# Out:
# Enter a number:  7
# Sum of prime numbers from 1 to 7 is: 17

# %%
def sum_of_odds(n):
    total = 0
    for i in range(1, n+1, 2): 
        total += i
    return total
n = int(input("Enter a number: "))

print("Sum of odd numbers from 1 to", n, "is:", sum_of_odds(n))
# Out:
# Enter a number:  5
# Sum of odd numbers from 1 to 5 is: 9
